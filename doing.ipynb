# %%
import pandas as pd


dataset = pd.read_csv('./dataset/c/dataset_2_without_entropy.csv', index_col='class')
dataset
# Out:
#          pack  preg_replace  str_replace  call_user_func  error_reporting  \
# class
# malware     1             1            0               0                0
# malware     0             0            1               0                0
# malware     0             0            0               1                0
# malware     0             0            0               0                1
# malware     0             0            9               0                2
# ...       ...           ...          ...             ...              ...
# benign      0             0            0               0                0
# benign      0             1            9               0                0
# benign      0             0            0               0                0
# benign      0             0            0               0                0
# benign      0             0            0               0                0
#
#          define  set_time_limit  shutdown57_login  md5  empty  ...  \
# ...
